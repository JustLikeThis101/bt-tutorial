# %%
import ffn

# %%
# %matplotlib inline

# %%
# download price data from Yahoo! Finance. By default,
# the Adj. Close will be used.
prices = ffn.get('aapl,msft', start='2010-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# let's compare the relative performance of each stock
# we will rebase here to get a common starting point for both securities
ax = prices.rebase().plot(figsize=(10, 5))

# %%
# now what do the return distributions look like?
returns = prices.to_returns().dropna()
ax = returns.hist(figsize=(10, 5))

# %%
# ok now what about some performance metrics?
stats = prices.calc_stats()
stats.display()
# Out:
# Stat                 aapl        msft
# -------------------  ----------  ----------
# Start                2010-01-04  2010-01-04
# End                  2024-05-17  2024-05-17
# Risk-free rate       0.00%       0.00%
#
# Total Return         2838.27%    1696.58%
# Daily Sharpe         0.98        0.91
# Daily Sortino        1.64        1.53
# CAGR                 26.53%      22.27%
# Max Drawdown         -43.80%     -37.15%
# Calmar Ratio         0.61        0.60
#
# MTD                  11.62%      8.13%
# 3m                   4.29%       4.18%
# 6m                   0.36%       14.03%
# YTD                  -1.12%      12.15%
# 1Y                   10.53%      34.87%
# 3Y (ann.)            15.21%      20.78%
# 5Y (ann.)            33.00%      28.02%
# 10Y (ann.)           25.83%      28.66%
# Since Incep. (ann.)  26.53%      22.27%
#
# Daily Sharpe         0.98        0.91
# Daily Sortino        1.64        1.53
# Daily Mean (ann.)    27.51%      23.45%
# Daily Vol (ann.)     28.08%      25.78%
# Daily Skew           -0.05       0.05
# Daily Kurt           5.17        7.65
# Best Day             11.98%      14.22%
# Worst Day            -12.86%     -14.74%
#
# Monthly Sharpe       1.04        1.08
# Monthly Sortino      2.18        2.25
# Monthly Mean (ann.)  28.20%      23.27%
# Monthly Vol (ann.)   27.17%      21.62%
# Monthly Skew         -0.05       0.08
# Monthly Kurt         -0.40       0.22
# Best Month           21.66%      19.63%
# Worst Month          -18.12%     -15.14%
#
# Yearly Sharpe        0.83        1.05
# Yearly Sortino       3.92        3.50
# Yearly Mean          27.63%      26.24%
# Yearly Vol           33.14%      25.06%
# Yearly Skew          0.39        -0.61
# Yearly Kurt          -0.29       0.03
# Best Year            88.96%      58.19%
# Worst Year           -26.40%     -28.02%
#
# Avg. Drawdown        -4.32%      -3.24%
# Avg. Drawdown Days   32.66       26.57
# Avg. Up Month        7.65%       5.57%
# Avg. Down Month      -5.19%      -4.51%
# Win Year %           71.43%      85.71%
# Win 12m %            78.40%      87.04%

# %%
# what about the drawdowns?
ax = stats.prices.to_drawdown_series().plot(figsize=(30, 15))
